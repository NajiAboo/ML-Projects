# %% [markdown]
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# https://facebook.github.io/prophet/

# %% [markdown]
# Installation can be done from
# pip install fbprophet

# %% [markdown]
# training set can be download from
# https://www.kaggle.com/currie32/crimes-in-chicago

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %%
crime_fb1 = pd.read_csv('Chicago_Crimes_2001_to_2004.csv', error_bad_lines = False )
crime_fb2 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv', error_bad_lines = False)
crime_fb3 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv', error_bad_lines = False)
crime_fb4 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv', error_bad_lines = False)
# Out:
# b'Skipping line 1513591: expected 23 fields, saw 24\n'
# b'Skipping line 533719: expected 23 fields, saw 24\n'
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
crime_df = pd.concat([crime_fb1,crime_fb2,crime_fb3,crime_fb4])

# %%
crime_df.head()
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0         879  4786321    HM399414  01/01/2004 12:01:00 AM
# 1        2544  4676906    HM278933  03/01/2003 12:00:00 AM
# 2        2919  4789749    HM402220  06/20/2004 11:00:00 AM
# 3        2927  4789765    HM402058  12/30/2004 08:00:00 PM
# 4        3302  4677901    HM275615  05/01/2003 01:00:00 AM
#
#                  Block  IUCR                Primary Type  \
# 0    082XX S COLES AVE  0840                       THEFT
# 1      004XX W 42ND PL  2825               OTHER OFFENSE
# 2  025XX N KIMBALL AVE  1752  OFFENSE INVOLVING CHILDREN
# 3   045XX W MONTANA ST  0840                       THEFT
# 4   111XX S NORMAL AVE  0841                       THEFT
#
#                       Description Location Description  Arrest  ...  Ward  \
# 0   FINANCIAL ID THEFT: OVER $300            RESIDENCE   False  ...   7.0
# 1         HARASSMENT BY TELEPHONE            RESIDENCE   False  ...  11.0
# ...

# %%
crime_df.tail()
# Out:
#          Unnamed: 0        ID Case Number                    Date  \
# 1456709     6250330  10508679    HZ250507  05/03/2016 11:33:00 PM
# 1456710     6251089  10508680    HZ250491  05/03/2016 11:30:00 PM
# 1456711     6251349  10508681    HZ250479  05/03/2016 12:15:00 AM
# 1456712     6253257  10508690    HZ250370  05/03/2016 09:07:00 PM
# 1456713     6253474  10508692    HZ250517  05/03/2016 11:38:00 PM
#
#                         Block  IUCR     Primary Type              Description  \
# 1456709       026XX W 23RD PL  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456710   073XX S HARVARD AVE  1310  CRIMINAL DAMAGE              TO PROPERTY
# 1456711       024XX W 63RD ST  041A          BATTERY      AGGRAVATED: HANDGUN
# 1456712  082XX S EXCHANGE AVE  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456713       001XX E 75TH ST  5007    OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  ...  Ward  Community Area  \
# ...

# %%
crime_df.shape
# Out:
# (7941282, 23)

# %%
plt.figure(figsize=(10,20))
sns.heatmap(crime_df.isnull(), char=False, cMap='YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-bee54a5b1716> in <module>
#       1 plt.figure(figsize=(10,20))
# ----> 2 sns.heatmap(crime_df.isnull(), char=False, cMap='YlGnBu')
#
# ~/.local/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     521     if square:
#     522         ax.set_aspect("equal")
# --> 523     plotter.plot(ax, cbar_ax, kwargs)
#     524     return ax
#     525
#
# ~/.local/lib/python3.6/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     275         # Draw the heatmap
#     276         mesh = ax.pcolormesh(self.plot_data, vmin=self.vmin, vmax=self.vmax,
# --> 277                              cmap=self.cmap, **kws)
#     278
# ...

# %%
crime_df.drop(['Unnamed: 0','ID','Case Number', 'IUCR','X Coordinate', 'Y Coordinate','Updated On','Year','FBI Code', 'Beat','Community Area', 'Location', 'District','Latitude','Longitude'], inplace=True, axis=1)

# %%
crime_df.head()
# Out:
#                      Date                Block                Primary Type  \
# 0  01/01/2004 12:01:00 AM    082XX S COLES AVE                       THEFT
# 1  03/01/2003 12:00:00 AM      004XX W 42ND PL               OTHER OFFENSE
# 2  06/20/2004 11:00:00 AM  025XX N KIMBALL AVE  OFFENSE INVOLVING CHILDREN
# 3  12/30/2004 08:00:00 PM   045XX W MONTANA ST                       THEFT
# 4  05/01/2003 01:00:00 AM   111XX S NORMAL AVE                       THEFT
#
#                       Description Location Description  Arrest  Domestic  Ward
# 0   FINANCIAL ID THEFT: OVER $300            RESIDENCE   False     False   7.0
# 1         HARASSMENT BY TELEPHONE            RESIDENCE   False      True  11.0
# 2   AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False     False  35.0
# 3   FINANCIAL ID THEFT: OVER $300                OTHER   False     False  31.0
# 4  FINANCIAL ID THEFT:$300 &UNDER            RESIDENCE   False     False  34.0

# %%
crime_df.Date = pd.to_datetime(crime_df.Date, format = '%m/%d/%Y %I:%M:%S %p')

# %% [raw]
# crime_df.Date

# %%
 crime_df.set_index([crime_df.Date])
# Out:
#                                    Date                 Block  \
# Date
# 2004-01-01 00:01:00 2004-01-01 00:01:00     082XX S COLES AVE
# 2003-03-01 00:00:00 2003-03-01 00:00:00       004XX W 42ND PL
# 2004-06-20 11:00:00 2004-06-20 11:00:00   025XX N KIMBALL AVE
# 2004-12-30 20:00:00 2004-12-30 20:00:00    045XX W MONTANA ST
# 2003-05-01 01:00:00 2003-05-01 01:00:00    111XX S NORMAL AVE
# ...                                 ...                   ...
# 2016-05-03 23:33:00 2016-05-03 23:33:00       026XX W 23RD PL
# 2016-05-03 23:30:00 2016-05-03 23:30:00   073XX S HARVARD AVE
# 2016-05-03 00:15:00 2016-05-03 00:15:00       024XX W 63RD ST
# 2016-05-03 21:07:00 2016-05-03 21:07:00  082XX S EXCHANGE AVE
# 2016-05-03 23:38:00 2016-05-03 23:38:00       001XX E 75TH ST
#
#                                    Primary Type  \
# Date
# 2004-01-01 00:01:00                       THEFT
# 2003-03-01 00:00:00               OTHER OFFENSE
# 2004-06-20 11:00:00  OFFENSE INVOLVING CHILDREN
# ...

# %%
crime_df.index = pd.DatetimeIndex(crime_df.Date)

# %%
crime_df['Primary Type'].value_counts()
# Out:
# THEFT                                1640506
# BATTERY                              1442716
# CRIMINAL DAMAGE                       923000
# NARCOTICS                             885431
# OTHER OFFENSE                         491922
# ASSAULT                               481661
# BURGLARY                              470958
# MOTOR VEHICLE THEFT                   370548
# ROBBERY                               300453
# DECEPTIVE PRACTICE                    280931
# CRIMINAL TRESPASS                     229366
# PROSTITUTION                           86401
# WEAPONS VIOLATION                      77429
# PUBLIC PEACE VIOLATION                 58548
# OFFENSE INVOLVING CHILDREN             51441
# CRIM SEXUAL ASSAULT                    29868
# SEX OFFENSE                            28707
# GAMBLING                               18806
# LIQUOR LAW VIOLATION                   17513
# INTERFERENCE WITH PUBLIC OFFICER       15710
# ARSON                                  13097
# ...

# %%
order_data = crime_df['Primary Type'].value_counts().iloc[:15].index

# %%
plt.figure(figsize= (15,10))
sns.countplot(y= 'Primary Type', data=crime_df, order = order_data)

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='Location Description', data=crime_df, order= crime_df['Location Description'].value_counts().iloc[:15].index)

# %%
crime_df.resample('Y').size()
# Out:
# Date
# 2001-12-31    568518
# 2002-12-31    490879
# 2003-12-31    475913
# 2004-12-31    388205
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: A-DEC, dtype: int64

# %%
crime_prophet = crime_df.resample('M').size().reset_index()

# %%
crime_prophet
# Out:
#           Date      0
# 0   2001-01-31  74995
# 1   2001-02-28  66288
# 2   2001-03-31  53122
# 3   2001-04-30  40166
# 4   2001-05-31  41876
# ..         ...    ...
# 188 2016-09-30  23235
# 189 2016-10-31  23314
# 190 2016-11-30  21140
# 191 2016-12-31  19580
# 192 2017-01-31  11357
#
# [193 rows x 2 columns]

# %%
crime_prophet.columns = ['Date', 'Crime Count']

# %%
crime_prophet
# Out:
#           Date  Crime Count
# 0   2001-01-31        74995
# 1   2001-02-28        66288
# 2   2001-03-31        53122
# 3   2001-04-30        40166
# 4   2001-05-31        41876
# ..         ...          ...
# 188 2016-09-30        23235
# 189 2016-10-31        23314
# 190 2016-11-30        21140
# 191 2016-12-31        19580
# 192 2017-01-31        11357
#
# [193 rows x 2 columns]

# %% [markdown]
# Need to change this to ds and y  for the facebook prophet

# %%
crime_prophet_final = crime_prophet.rename(columns = {'Date':'ds','Crime Count':'y'})

# %%
crime_prophet_final
# Out:
#             ds      y
# 0   2001-01-31  74995
# 1   2001-02-28  66288
# 2   2001-03-31  53122
# 3   2001-04-30  40166
# 4   2001-05-31  41876
# ..         ...    ...
# 188 2016-09-30  23235
# 189 2016-10-31  23314
# 190 2016-11-30  21140
# 191 2016-12-31  19580
# 192 2017-01-31  11357
#
# [193 rows x 2 columns]

# %%
m = Prophet()

# %%
m.fit(crime_prophet_final)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
forcast = m.predict(future)

# %%
forcast.head(1)
# Out:
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2001-01-31  40565.476271  22583.645946  53820.510234  40565.476271
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  40565.476271    -1575.605098          -1575.605098          -1575.605098
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0 -1575.605098  -1575.605098  -1575.605098                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  38989.871172

# %%
figure = m.plot(forcast, xlabel = 'Date', ylabel=" Rate")
